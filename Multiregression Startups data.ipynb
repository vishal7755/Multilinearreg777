# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from numpy.polynomial.polynomial import polyfit
from sklearn.linear_model import LinearRegression
import seaborn as sn
import statsmodels.stats.tests.test_influence
from sklearn.feature_selection import RFE
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# # _Prepare a prediction model for profit of 50startups data
# # Do transformations for getting better predictions of profit and
# # make a table containing R^2 value for each prepared model.

# %%
df1=pd.read_csv("C:/Users/DELL/Downloads/50_Startups.csv")
df1
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
sn.pairplot(df1)

# %%
corr=df1.corr()

# %%
sn.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Regression Model

# %%
df1 = pd.get_dummies(df1, columns=['State'])

# %%
X = df1[['R&D Spend','Administration', 'Marketing Spend', 'State_California', 'State_Florida', 'State_New York']]
Y = df1[['Profit']]

# %%
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Sun, 06 Mar 2022   Prob (F-statistic):           1.34e-27
# Time:                        11:47:35   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # R sq and p Value of the Model is Good and the model can be accepted. However as you can see not all variables have acceptable p value. Thus we have Multicollinearity issue in our Data Frame

# %% [markdown]
# # Multicolinearity
# # 1 cook distance

# %%
infl = model.get_influence()

# %%
summ_df = infl.summary_frame()

# %%
summ_df.sort_values('cooks_d', ascending=False)
# Out:
#     dfb_R&D Spend  dfb_Administration  dfb_Marketing Spend  \
# 49       0.578956           -0.114232             0.080954
# 48      -0.112734            0.701599             0.418630
# 45      -0.212843            0.091394            -0.189969
# 14      -0.221204           -0.257240             0.142195
# 36      -0.379353            0.189523             0.218405
# 38      -0.189819           -0.313449             0.109261
# 15      -0.208289            0.066627             0.071114
# 46       0.434369           -0.142646            -0.364064
# 19       0.252210            0.039342            -0.342025
# 27       0.271462           -0.146112            -0.339679
# 2        0.197811           -0.174765            -0.013702
# 3        0.110000           -0.049701             0.073783
# 43      -0.090858            0.058906            -0.085052
# 10       0.186811           -0.137400            -0.159583
# 12       0.069420            0.010085            -0.048411
# ...

# %%
infl.plot_influence()

# %% [markdown]
# # Index 48 and 49 has highest Cook's Distance
# # 2 VIF

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif.round(1)
# Out:
#    VIF Factor          features
# 0         2.5         R&D Spend
# 1         1.2    Administration
# 2         2.4   Marketing Spend
# 3         9.0  State_California
# 4         9.4     State_Florida
# 5         9.2    State_New York

# %% [markdown]
# # Admiistration has lowest varience

# %%
# remove administration fro data frame
df2 = df1[['R&D Spend', 'Marketing Spend', 'State_California', 'State_Florida', 'State_New York']]

# %%
new_model = sm.OLS(Y, df2).fit()
new_predictions = new_model.predict(df2)

# %%
new_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     215.8
# Date:                Sun, 06 Mar 2022   Prob (F-statistic):           9.72e-29
# Time:                        11:54:45   Log-Likelihood:                -525.53
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1071.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # All the variable are significant
# # FINAL MODEL

# %%
# remove inexe with highest cook distance
df3 = df1.drop(df1.index[[49,48]])

# %%
new_X = df3[['R&D Spend', 'Marketing Spend', 'State_California', 'State_Florida', 'State_New York']]
new_Y = df3[['Profit']]

# %%
final_model = sm.OLS(new_Y, new_X).fit()
predictions = final_model.predict(new_X)

# %%
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     265.9
# Date:                Sun, 06 Mar 2022   Prob (F-statistic):           1.02e-29
# Time:                        11:58:38   Log-Likelihood:                -494.30
# No. Observations:                  48   AIC:                             998.6
# Df Residuals:                      43   BIC:                             1008.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Model has accpetable p Value and R sq value, we can still improve the R squre value.
# # Sq root transformation of X

# %%
X_sqrt = np.sqrt(df3[['R&D Spend', 'Marketing Spend', 'State_California', 'State_Florida', 'State_New York']])

# %%
model3 = sm.OLS(new_Y, X_sqrt).fit()
predictions3 = model3.predict(X_sqrt)

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     84.44
# Date:                Sun, 06 Mar 2022   Prob (F-statistic):           8.67e-20
# Time:                        12:01:12   Log-Likelihood:                -519.91
# No. Observations:                  48   AIC:                             1050.
# Df Residuals:                      43   BIC:                             1059.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Sq root transormation of Y

# %%
Y_sqrt = np.sqrt(df3['Profit'])

# %%
model4 = sm.OLS(Y_sqrt, new_X).fit()
predictions4 = model4.predict(new_X)
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     223.3
# Date:                Sun, 06 Mar 2022   Prob (F-statistic):           3.68e-28
# Time:                        12:02:13   Log-Likelihood:                -185.87
# No. Observations:                  48   AIC:                             381.7
# Df Residuals:                      43   BIC:                             391.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Sq root transormation of X & Y

# %%
model5 = sm.OLS(Y_sqrt, X_sqrt).fit()
predictions5 = model5.predict(X_sqrt)
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     141.7
# Date:                Sun, 06 Mar 2022   Prob (F-statistic):           3.64e-24
# Time:                        12:02:54   Log-Likelihood:                -196.16
# No. Observations:                  48   AIC:                             402.3
# Df Residuals:                      43   BIC:                             411.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # OUTPUT
# Model 5 as it has the best R square value 1 - p-value < 0.01
#
# coefficient == 1 Thus if the value of x increased by 1, the predicted value of Price will increase by 1
#
# Adj. R-sqared == 1
